# %%
nums = [5, 3, 7, 9, 2, 56, 12, 24, 18, 45, 98, 24, -10, 0, -1]

targert = 90 

n = len(nums)
for i in range(n):
    if nums[i] == targert:
        print(i)
        break

# Find the index of target in nums
else:
    print(-1)
# Out:
# -1
